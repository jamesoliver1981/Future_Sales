# %%
#play with pixies
import pandas as pd
from matplotlib import pyplot as plt
import pandas as pd
import os
import pixiedust as pix

# %%
dateCols = ['date']
train2=pd.read_csv("/home/cdsw/01_future-sales/data/train_plus_not_imputted.csv",parse_dates=dateCols)

# %%
pix.display(train2)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigureb8d4f14a" class="pd_save is-viewer-good" style="overflow-x:auto">
#             <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
# ...

# %%
set(train2[train2.item_category_id==40].item_name.tail(15))
# Out:
# {'STARПЕРЦЫ',
#  'WINX КЛУБ. Тайна Морской Бездны (регион)',
#  'А ЗОРИ ЗДЕСЬ ТИХИЕ (2015)',
#  'АДЪЮТАНТ ЕГО ПРЕВОСХОДИТЕЛЬСТВА  Серии 1-5  2DVD',
#  'АЛИСА В СТРАНЕ ЧУДЕС м/ф (регион)',
#  'БРИЛЛИАНТОВАЯ РУКА (rem)',
#  'В БОЙ ИДУТ ОДНИ СТАРИКИ (регион)',
#  'В ЛЕСУ РОДИЛАСЬ ЁЛОЧКА (+мультфильм в подарок)',
#  'В МИРЕ СКАЗОК (Выпуск 2)',
#  'В МИРЕ СКАЗОК (Выпуск 3)',
#  'ВНЕ/СЕБЯ'}
